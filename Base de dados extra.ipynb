# %%
import pandas as pd

# %%
json = open('dados extra/aluguel.json')
print(json.read())
# Out:
# [{"Tipo":"Quitinete","Bairro":"Copacabana","Quartos":1,"Vagas":0,"Suites":0,"Area":40,"Valor":1700.0,"Condominio":500.0,"IPTU":60.0},
# {"Tipo":"Casa","Bairro":"Jardim Bot\u00e2nico","Quartos":2,"Vagas":0,"Suites":1,"Area":100,"Valor":7000.0,"Condominio":null,"IPTU":null},
# {"Tipo":"Conjunto Comercial\/Sala","Bairro":"Barra da Tijuca","Quartos":0,"Vagas":4,"Suites":0,"Area":150,"Valor":5200.0,"Condominio":4020.0,"IPTU":1111.0},
# {"Tipo":"Apartamento","Bairro":"Centro","Quartos":1,"Vagas":0,"Suites":0,"Area":15,"Valor":800.0,"Condominio":390.0,"IPTU":20.0},
# {"Tipo":"Apartamento","Bairro":"Higien\u00f3polis","Quartos":1,"Vagas":0,"Suites":0,"Area":48,"Valor":800.0,"Condominio":230.0,"IPTU":null},
# {"Tipo":"Apartamento","Bairro":"Vista Alegre","Quartos":3,"Vagas":1,"Suites":0,"Area":70,"Valor":1200.0,"Condominio":null,"IPTU":null},
# {"Tipo":"Apartamento","Bairro":"Cachambi","Quartos":2,"Vagas":0,"Suites":0,"Area":50,"Valor":1300.0,"Condominio":301.0,"IPTU":17.0},
# ...

# %%
df_json = pd.read_json('dados extra/aluguel.json')
df_json
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# ...

# %%
txt = open('dados extra/aluguel.txt')
print(txt.read())
# Out:
# Tipo	Bairro	Quartos	Vagas	Suites	Area	Valor	Condominio	IPTU
# Quitinete	Copacabana	1	0	0	40	1700	500	60
# Casa	Jardim BotÃ¢nico	2	0	1	100	7000
# Conjunto Comercial/Sala	Barra da Tijuca	0	4	0	150	5200	4020	1111
# Apartamento	Centro	1	0	0	15	800	390	20
# Apartamento	HigienÃ³polis	1	0	0	48	800	230
# Apartamento	Vista Alegre	3	1	0	70	1200
# Apartamento	Cachambi	2	0	0	50	1300	301	17
# Casa de CondomÃ­nio	Barra da Tijuca	5	4	5	750	22000
# Casa de CondomÃ­nio	Ramos	2	2	0	65	1000
# Conjunto Comercial/Sala	Centro	0	3	0	695	35000	19193	3030

# %%
df_txt = pd.read_table('dados extra/aluguel.txt')
df_txt
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# ...

# %%
df_xlsx = pd.read_excel('dados extra/aluguel.xlsx')
df_xlsx
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# ...

# %%
df_html = pd.read_html('dados extra/dados_html_1.html')
df_html
# Out:
# [  FAIXA ETÁRIA UNAFISCO SAÚDE SOFT II SOFT PARTICIPATIVO      UNIQUE
#  0      00 A 18               R$218,99           R$192,60    R$334,48
#  1      19 A 23               R$263,63           R$207,67    R$380,06
#  2      24 A 28               R$322,44           R$224,26    R$464,39
#  3      29 A 33               R$402,05           R$258,63    R$566,68
#  4      34 A 38               R$455,17           R$306,37    R$664,61
#  5      39 A 43               R$489,29           R$417,93    R$742,72
#  6      44 A 48               R$582,65           R$495,24    R$869,47
#  7      49 A 53               R$718,86           R$562,64  R$1.046,29
#  8      54 A 58               R$908,54           R$721,00  R$1.355,74
#  9   59 OU MAIS             R$1.244,50         R$1.151,62  R$2.003,53]

# %%
df_html = pd.read_html('https://www.ssp.sp.gov.br/estatistica/pesquisa.aspx')
df_html
# Out:
# [                                        Natureza      Jan      Fev      Mar  \
#  0          OCORRÊNCIAS DE PORTE DE ENTORPECENTES  911.000    1.238    1.202
#  1        OCORRÊNCIAS DE TRÁFICO DE ENTORPECENTES    2.586    2.634    2.914
#  2   OCORRÊNCIAS DE APREENSÃO DE ENTORPECENTES(1)  370.000  407.000  422.000
#  3            OCORRÊNCIAS DE PORTE ILEGAL DE ARMA  313.000  315.000  393.000
#  4                Nº DE ARMAS DE FOGO APREENDIDAS  762.000  875.000  971.000
#  5                      Nº DE FLAGRANTES LAVRADOS    6.875    7.322    8.205
#  6      Nº DE INFRATORES APREENDIDOS EM FLAGRANTE  641.000  691.000  779.000
#  7       Nº DE INFRATORES APREENDIDOS POR MANDADO  109.000  138.000  181.000
#  8              Nº DE PESSOAS PRESAS EM FLAGRANTE    8.097    8.564    9.629
#  9               Nº DE PESSOAS PRESAS POR MANDADO    4.110    4.758    5.504
#  10                       Nº DE PRISÕES EFETUADAS   10.661   11.635   13.405
# ...

# %%
df_html = pd.read_html('https://www.ssp.sp.gov.br/estatistica/pesquisa.aspx')

# %%
len(df_html)
# Out:
# 3

# %%
df_html[0]
# Out:
#                                         Natureza      Jan      Fev      Mar  \
# 0          OCORRÊNCIAS DE PORTE DE ENTORPECENTES  911.000    1.238    1.202
# 1        OCORRÊNCIAS DE TRÁFICO DE ENTORPECENTES    2.586    2.634    2.914
# 2   OCORRÊNCIAS DE APREENSÃO DE ENTORPECENTES(1)  370.000  407.000  422.000
# 3            OCORRÊNCIAS DE PORTE ILEGAL DE ARMA  313.000  315.000  393.000
# 4                Nº DE ARMAS DE FOGO APREENDIDAS  762.000  875.000  971.000
# 5                      Nº DE FLAGRANTES LAVRADOS    6.875    7.322    8.205
# 6      Nº DE INFRATORES APREENDIDOS EM FLAGRANTE  641.000  691.000  779.000
# 7       Nº DE INFRATORES APREENDIDOS POR MANDADO  109.000  138.000  181.000
# 8              Nº DE PESSOAS PRESAS EM FLAGRANTE    8.097    8.564    9.629
# 9               Nº DE PESSOAS PRESAS POR MANDADO    4.110    4.758    5.504
# 10                       Nº DE PRISÕES EFETUADAS   10.661   11.635   13.405
# ...

# %%
df_html[1]
# Out:
#                                         Natureza      Jan      Fev      Mar  \
# 0          OCORRÊNCIAS DE PORTE DE ENTORPECENTES    1.215    1.101    1.088
# 1        OCORRÊNCIAS DE TRÁFICO DE ENTORPECENTES    3.323    3.489    3.625
# 2   OCORRÊNCIAS DE APREENSÃO DE ENTORPECENTES(1)  412.000  392.000  410.000
# 3            OCORRÊNCIAS DE PORTE ILEGAL DE ARMA  311.000  353.000  391.000
# 4                Nº DE ARMAS DE FOGO APREENDIDAS  915.000  950.000    1.048
# 5                      Nº DE FLAGRANTES LAVRADOS    7.686    7.655    8.081
# 6      Nº DE INFRATORES APREENDIDOS EM FLAGRANTE  777.000  790.000  852.000
# 7       Nº DE INFRATORES APREENDIDOS POR MANDADO  118.000  198.000  182.000
# 8              Nº DE PESSOAS PRESAS EM FLAGRANTE    9.050    9.108    9.550
# 9               Nº DE PESSOAS PRESAS POR MANDADO    4.356    4.737    4.593
# 10                       Nº DE PRISÕES EFETUADAS   11.655   11.878   12.171
# ...

# %%
df_html[2]
# Out:
#                                         Natureza      Jan      Fev      Mar  \
# 0          OCORRÊNCIAS DE PORTE DE ENTORPECENTES    1.450    1.331  956.000
# 1        OCORRÊNCIAS DE TRÁFICO DE ENTORPECENTES    3.306    3.204    2.957
# 2   OCORRÊNCIAS DE APREENSÃO DE ENTORPECENTES(1)  347.000  322.000  314.000
# 3            OCORRÊNCIAS DE PORTE ILEGAL DE ARMA  371.000  349.000  363.000
# 4                Nº DE ARMAS DE FOGO APREENDIDAS    1.012    1.004  986.000
# 5                      Nº DE FLAGRANTES LAVRADOS    7.708    7.865    7.577
# 6      Nº DE INFRATORES APREENDIDOS EM FLAGRANTE    1.019  981.000  932.000
# 7       Nº DE INFRATORES APREENDIDOS POR MANDADO  232.000  263.000  176.000
# 8              Nº DE PESSOAS PRESAS EM FLAGRANTE    8.965    9.144    9.032
# 9               Nº DE PESSOAS PRESAS POR MANDADO    6.346    6.184    4.886
# 10                       Nº DE PRISÕES EFETUADAS   13.442   13.304   12.036
# ...
